# %% [markdown]
# ### 1. MongoDB에 웹스크래핑 데이터 저장하기
# * MongoDB에 연결
# * database와 collection 생성
# * actors.json 읽어서 insert_many()

# %%
import pymongo
import json

con = pymongo.MongoClient(host='localhost',port=27017)
print(con)

db = con.member_db
print(db)

#collection drop 
db.drop_collection('actors')

col = db.actors
print(col)

with open('data/actors2.json','r',encoding='utf8') as file:
    json_data = json.load(file)
    col.insert_many(json_data)

print('document 건수', col.estimated_document_count())
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'member_db')
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'member_db'), 'actors')
# document 건수 588

# %%
#컬렉션의 find()를 사용한 함수 정의
def print_find_document(criteria, projection):
    for idx, member_doc in enumerate(col.find(criteria, projection),1):
        print(idx, member_doc)

# %%
#컬렉션의 aggregate()를 사용한 함수 정의
def print_aggregate_document(*args):
    agg_list = []
    for arg in args:
        agg_list.append(arg)
    print(agg_list)
    
    for agg_doc in col.aggregate(agg_list):
        print(agg_doc)

# %%
#1. 랭킹 1 ~ 50 인 배우의 배우이름,랭킹,흥행지수,소속사,출연영화
criteria = {
    '랭킹':{'$lte':50}
}
projection = {
    '_id':0,'랭킹':1,'배우이름':1,'흥행지수':1,'소속사':1,'출연영화':1
}

print_find_document(criteria, projection)
# Out:
# 1 {'배우이름': '성동일', '랭킹': 1, '흥행지수': 139484, '출연영화': ['방법', '어쩌다 가족', '바퀴 달린 집']}
# 2 {'배우이름': '하지원', '랭킹': 2, '흥행지수': 104613, '출연영화': ['담보', '초콜릿', '갈릴레오 : 깨어난 우주']}
# 3 {'배우이름': '김희원', '랭킹': 3, '흥행지수': 81024, '소속사': 'DMS커뮤니케이션즈', '출연영화': ['바퀴 달린 집', '담보', '신의 한 수: 귀수편']}
# 4 {'배우이름': '유아인', '랭킹': 4, '흥행지수': 42326, '출연영화': ['소리도 없이', '＃살아있다', '도올아인 오방간다']}
# 5 {'배우이름': '박소이', '랭킹': 5, '흥행지수': 34871, '출연영화': ['호텔 레이크', '담보', '다시, 봄']}
# 6 {'배우이름': '유재명', '랭킹': 6, '흥행지수': 28202, '출연영화': ['소리도 없이', '소방관', '이태원 클라쓰']}
# 7 {'배우이름': '나문희', '랭킹': 7, '흥행지수': 26302, '출연영화': ['오! 문희', '영웅', '감쪽같은 그녀']}
# 8 {'배우이름': '이희준', '랭킹': 8, '흥행지수': 21096, '출연영화': ['오! 문희', '병훈의 하루', '병훈의 하루']}
# 9 {'배우이름': '김호중', '랭킹': 9, '흥행지수': 20580, '출연영화': ['그대, 고맙소 : 김호중 생애 첫 팬미팅 무비', '김창옥쇼', '위대한 배태랑']}
# 10 {'배우이름': '고아성', '랭킹': 10, '흥행지수': 18029, '소속사': '아티스트컴퍼니', '출연영화': ['바닷길 선발대', '항거:유관순 이야기', '삼진그룹 영어토익반']}
# 11 {'배우이름': '이솜', '랭킹': 11, '흥행지수': 16641, '소속사': '아티스트컴퍼니', '출연영화': ['울렁울렁 울렁대는 가슴안고', '삼진그룹 영어토익반', '구해줘 시즌 2']}
# 12 {'배우이름': '최원영', '랭킹': 12, '흥행지수': 15879, '출연영화': ['오! 문희', '쌍갑포차', '앨리스']}
# 13 {'배우이름': '박혜수', '랭킹': 13, '흥행지수': 15254, '출연영화': ['삼진그룹 영어토익반', '스윙키즈', '내성적인 보스']}
# 14 {'배우이름': '곽도원', '랭킹': 14, '흥행지수': 14917, '출연영화': ['소방관', '강철비2: 정상회담', '국제수사']}
# 15 {'배우이름': '김대명', '랭킹': 15, '흥행지수': 14674, '출연영화': ['슬기로운 의사생활', '더러운 돈에 손대지 마라', '국제수사']}
# 16 {'배우이름': '문승아', '랭킹': 16, '흥행지수': 14101, '출연영화': ['소리도 없이', '흩어진 밤']}
# 17 {'배우이름': '조현철', '랭킹': 17, '흥행지수': 13868, '출연영화': ['더러운 돈에 손대지 마라', '영화로운 나날', '삼진그룹 영어토익반']}
# 18 {'배우이름': '김종수', '랭킹': 18, '흥행지수': 12482, '소속사': '아티스트컴퍼니', '출연영화': ['드림 (가제)', '시동', '나를 찾아줘']}
# 19 {'배우이름': '김상호', '랭킹': 19, '흥행지수': 12410, '소속사': '심엔터테인먼트', '출연영화': ['킹덤 시즌 2', '앨리스', '양자물리학']}
# 20 {'배우이름': '신민아', '랭킹': 20, '흥행지수': 12132, '출연영화': ['디바', '휴가', '보좌관 - 당신이 모르는 이야기']}
# 21 {'배우이름': '장혁', '랭킹': 21, '흥행지수': 11796, '소속사': '싸이더스 HQ', '출연영화': ['검객', '본 대로 말하라', '요트원정대 : 더 비기닝']}
# 22 {'배우이름': '김원해', '랭킹': 22, '흥행지수': 11094, '출연영화': ['우아한 친구들', '스타트업', '계약우정']}
# 23 {'배우이름': '황정민', '랭킹': 23, '흥행지수': 11042, '소속사': '예당엔터테인먼트', '출연영화': ['다만 악에서 구하소서', '교섭', '공작']}
# 24 {'배우이름': '박지영', '랭킹': 24, '흥행지수': 10668, '출연영화': ['호텔 레이크', '오! 문희', '내가 가장 예뻤을 때']}
# 25 {'배우이름': '이선호', '랭킹': 25, '흥행지수': 10488, '출연영화': ['극장판 포켓몬스터 뮤츠의 역습 EVOLUTION', '극장판 프리즘스톤 올스타 셀렉션', '극장판 포켓몬스터 베스트위시: 신의 속도 게노세크트 뮤츠의 각성']}
# 26 {'배우이름': '유진우', '랭킹': 26, '흥행지수': 10154, '출연영화': ['국제수사']}
# 27 {'배우이름': '김현수', '랭킹': 27, '흥행지수': 9830, '출연영화': ['검객', '펜트하우스', '지금 만나러 갑니다']}
# 28 {'배우이름': '배해선', '랭킹': 28, '흥행지수': 9707, '출연영화': ['시네마틱드라마 SF8', '앨리스', '시네마틱드라마 SF8 - 일주일 만에 사랑할 순 없다']}
# 29 {'배우이름': '손현주', '랭킹': 29, '흥행지수': 9025, '소속사': '페이스 엔터테인먼트', '출연영화': ['이태원 클라쓰', '모범형사', '한산: 용의 출현']}
# 30 {'배우이름': '백현진', '랭킹': 30, '흥행지수': 8321, '출연영화': ['삼진그룹 영어토익반', '내일 그대와', '당신자신과 당신의 것']}
# 31 {'배우이름': '이유영', '랭킹': 31, '흥행지수': 8088, '출연영화': ['시네마틱드라마 SF8 - 간호중', '시네마틱드라마 SF8', '디바']}
# 32 {'배우이름': '조재윤', '랭킹': 32, '흥행지수': 7923, '출연영화': ['주문 바다요', '모범형사', '영웅']}
# 33 {'배우이름': '정만식', '랭킹': 33, '흥행지수': 7864, '출연영화': ['검객', '배가본드', '보좌관 2 - 세상을 움직이는 사람들']}
# 34 {'배우이름': '이정재', '랭킹': 34, '흥행지수': 7361, '소속사': '아티스트컴퍼니', '출연영화': ['다만 악에서 구하소서', '사바하', '보좌관 – 세상을 움직이는 사람들']}
# 35 {'배우이름': 'RM', '랭킹': 35, '흥행지수': 7258, '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 36 {'배우이름': '임영웅', '랭킹': 36, '흥행지수': 7205, '출연영화': ['미스터트롯: 더 무비', '뽕숭아학당', '2020 트롯 어워즈']}
# 37 {'배우이름': '이성욱', '랭킹': 37, '흥행지수': 6934, '출연영화': ['유체이탈자', '365 : 운명을 거스르는 1년', '삼진그룹 영어토익반']}
# 38 {'배우이름': '신동미', '랭킹': 38, '흥행지수': 6773, '출연영화': ['하이바이, 마마!', '모범형사', '청춘기록']}
# 39 {'배우이름': '이정현', '랭킹': 39, '흥행지수': 6444, '소속사': '에이바 앤 엔터테인먼트', '출연영화': ['반도', '죽지않는 인간들의 밤', '두번할까요']}
# 40 {'배우이름': '진', '랭킹': 40, '흥행지수': 6221, '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 41 {'배우이름': '영탁', '랭킹': 41, '흥행지수': 6004, '출연영화': ['미스터트롯: 더 무비', '뽕숭아학당', '꼰대인턴 방구석 팬미팅 : 끝나지 말란 말야']}
# 42 {'배우이름': '이나경', '랭킹': 42, '흥행지수': 5898, '출연영화': ['검객', '아임쏘리 강남구']}
# 43 {'배우이름': '신승환', '랭킹': 43, '흥행지수': 5641, '출연영화': ['들리나요?', '국제수사', '목격자']}
# 44 {'배우이름': '이주영', '랭킹': 44, '흥행지수': 5547, '출연영화': ['아무도 없는 곳', '삼진그룹 영어토익반', '독전']}
# 45 {'배우이름': '이진주', '랭킹': 45, '흥행지수': 5456, '출연영화': ['오! 문희']}
# 46 {'배우이름': '홍시호', '랭킹': 46, '흥행지수': 5244, '출연영화': ['극장판 포켓몬스터 뮤츠의 역습 EVOLUTION', '마징가 Z 인피니티', '극장판 레이디버그: 미라클스톤의 비밀']}
# 47 {'배우이름': '슈가', '랭킹': 47, '흥행지수': 5184, '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 48 {'배우이름': '김성오', '랭킹': 48, '흥행지수': 5093, '출연영화': ['해적: 도깨비 깃발', '우아한 친구들', '해치지않아']}
# 49 {'배우이름': '이찬원', '랭킹': 49, '흥행지수': 4803, '출연영화': ['미스터트롯: 더 무비', '뽕숭아학당']}
# 50 {'배우이름': '이한서', '랭킹': 50, '흥행지수': 4513, '출연영화': ['국제수사', '수상한 장모', '착한마녀전']}

# %%
#흥행지수가 20000 보다 크거나 같은 배우는?
for actor in col.find({'흥행지수':{'$gte':20000}},{'_id':0,'배우이름':1,'흥행지수':1})\
.sort('배우이름',pymongo.DESCENDING):
    print(actor)
# Out:
# {'배우이름': '하지원', '흥행지수': 104613}
# {'배우이름': '이희준', '흥행지수': 21096}
# {'배우이름': '유재명', '흥행지수': 28202}
# {'배우이름': '유아인', '흥행지수': 42326}
# {'배우이름': '성동일', '흥행지수': 139484}
# {'배우이름': '박소이', '흥행지수': 34871}
# {'배우이름': '나문희', '흥행지수': 26302}
# {'배우이름': '김희원', '흥행지수': 81024}
# {'배우이름': '김호중', '흥행지수': 20580}

# %%
#$exists 연산자를 사용
#특기 필드가 존재하지 않은 경우와 존재하는 경우 count
#print( col.find({'특기':{'$exists':True}}).count() )
print(col.count_documents({'특기':{'$exists':True}}))
print(col.count_documents({'특기':{'$exists':False}}))
# Out:
# 55
# 533

# %%
#다른 이름이 필드가 존재하면서 다른 이름이 방탄소년단 인 배우는?
criteria = {'다른 이름':{'$exists':True},'다른 이름':{'$regex':'방탄소년단'}}
#criteria = {'다른 이름':{'$regex':'방탄소년단'}}
    
projection = {
    '_id':0,'랭킹':1,'배우이름':1,'흥행지수':1,'다른 이름':1,'출연영화':1
}
print_find_document(criteria, projection)
# Out:
# 1 {'배우이름': 'RM', '랭킹': 35, '흥행지수': 7258, '다른 이름': '김남준; 방탄소년단; RM', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 2 {'배우이름': '진', '랭킹': 40, '흥행지수': 6221, '다른 이름': '김석진; 방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 3 {'배우이름': '슈가', '랭킹': 47, '흥행지수': 5184, '다른 이름': '민윤기; 방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 4 {'배우이름': '제이홉', '랭킹': 51, '흥행지수': 4147, '다른 이름': '정호석; 방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 5 {'배우이름': '지민', '랭킹': 61, '흥행지수': 3110, '다른 이름': '박지민, 방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 6 {'배우이름': '뷔', '랭킹': 68, '흥행지수': 2074, '다른 이름': '방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 7 {'배우이름': '정국', '랭킹': 85, '흥행지수': 1037, '다른 이름': '전정국; 방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '추석특집 ALL ABOUT BTS']}

# %%
# $nor ( not or )
# 흥행지수 >= 15000 or 성별 = 남
#$or 연산자
print(col.count_documents({'$or':[{'흥행지수':{'$gte':15000}},{'성별':'남'}]}))
#$nor 연산자
print(col.count_documents({'$nor':[{'흥행지수':{'$lte':15000}},{'성별':'여'}]}))
# Out:
# 337
# 7

# %%
criteria = {'$or':[{'흥행지수':{'$gte':15000}},{'성별':'남'}]}
#criteria = {'$nor':[{'흥행지수':{'$lte':15000}},{'성별':'여'}]}
print_find_document(criteria, projection)
# Out:
# 1 {'배우이름': '성동일', '랭킹': 1, '흥행지수': 139484, '출연영화': ['방법', '어쩌다 가족', '바퀴 달린 집']}
# 2 {'배우이름': '하지원', '랭킹': 2, '흥행지수': 104613, '출연영화': ['담보', '초콜릿', '갈릴레오 : 깨어난 우주']}
# 3 {'배우이름': '김희원', '랭킹': 3, '흥행지수': 81024, '출연영화': ['바퀴 달린 집', '담보', '신의 한 수: 귀수편']}
# 4 {'배우이름': '유아인', '랭킹': 4, '흥행지수': 42326, '다른 이름': '엄홍식', '출연영화': ['소리도 없이', '＃살아있다', '도올아인 오방간다']}
# 5 {'배우이름': '박소이', '랭킹': 5, '흥행지수': 34871, '출연영화': ['호텔 레이크', '담보', '다시, 봄']}
# 6 {'배우이름': '유재명', '랭킹': 6, '흥행지수': 28202, '출연영화': ['소리도 없이', '소방관', '이태원 클라쓰']}
# 7 {'배우이름': '나문희', '랭킹': 7, '흥행지수': 26302, '출연영화': ['오! 문희', '영웅', '감쪽같은 그녀']}
# 8 {'배우이름': '이희준', '랭킹': 8, '흥행지수': 21096, '출연영화': ['오! 문희', '병훈의 하루', '병훈의 하루']}
# 9 {'배우이름': '김호중', '랭킹': 9, '흥행지수': 20580, '출연영화': ['그대, 고맙소 : 김호중 생애 첫 팬미팅 무비', '김창옥쇼', '위대한 배태랑']}
# 10 {'배우이름': '고아성', '랭킹': 10, '흥행지수': 18029, '출연영화': ['바닷길 선발대', '항거:유관순 이야기', '삼진그룹 영어토익반']}
# 11 {'배우이름': '이솜', '랭킹': 11, '흥행지수': 16641, '출연영화': ['울렁울렁 울렁대는 가슴안고', '삼진그룹 영어토익반', '구해줘 시즌 2']}
# 12 {'배우이름': '최원영', '랭킹': 12, '흥행지수': 15879, '출연영화': ['오! 문희', '쌍갑포차', '앨리스']}
# 13 {'배우이름': '박혜수', '랭킹': 13, '흥행지수': 15254, '출연영화': ['삼진그룹 영어토익반', '스윙키즈', '내성적인 보스']}
# 14 {'배우이름': '곽도원', '랭킹': 14, '흥행지수': 14917, '다른 이름': '곽병규', '출연영화': ['소방관', '강철비2: 정상회담', '국제수사']}
# 15 {'배우이름': '김대명', '랭킹': 15, '흥행지수': 14674, '출연영화': ['슬기로운 의사생활', '더러운 돈에 손대지 마라', '국제수사']}
# 16 {'배우이름': '조현철', '랭킹': 17, '흥행지수': 13868, '출연영화': ['더러운 돈에 손대지 마라', '영화로운 나날', '삼진그룹 영어토익반']}
# 17 {'배우이름': '김종수', '랭킹': 18, '흥행지수': 12482, '출연영화': ['드림 (가제)', '시동', '나를 찾아줘']}
# 18 {'배우이름': '김상호', '랭킹': 19, '흥행지수': 12410, '출연영화': ['킹덤 시즌 2', '앨리스', '양자물리학']}
# 19 {'배우이름': '장혁', '랭킹': 21, '흥행지수': 11796, '다른 이름': '정용준', '출연영화': ['검객', '본 대로 말하라', '요트원정대 : 더 비기닝']}
# 20 {'배우이름': '김원해', '랭킹': 22, '흥행지수': 11094, '출연영화': ['우아한 친구들', '스타트업', '계약우정']}
# 21 {'배우이름': '황정민', '랭킹': 23, '흥행지수': 11042, '출연영화': ['다만 악에서 구하소서', '교섭', '공작']}
# 22 {'배우이름': '유진우', '랭킹': 26, '흥행지수': 10154, '다른 이름': '이유진', '출연영화': ['국제수사']}
# 23 {'배우이름': '손현주', '랭킹': 29, '흥행지수': 9025, '출연영화': ['이태원 클라쓰', '모범형사', '한산: 용의 출현']}
# 24 {'배우이름': '백현진', '랭킹': 30, '흥행지수': 8321, '다른 이름': '어어부 밴드;어어부 프로젝트', '출연영화': ['삼진그룹 영어토익반', '내일 그대와', '당신자신과 당신의 것']}
# 25 {'배우이름': '조재윤', '랭킹': 32, '흥행지수': 7923, '출연영화': ['주문 바다요', '모범형사', '영웅']}
# 26 {'배우이름': '정만식', '랭킹': 33, '흥행지수': 7864, '출연영화': ['검객', '배가본드', '보좌관 2 - 세상을 움직이는 사람들']}
# 27 {'배우이름': '이정재', '랭킹': 34, '흥행지수': 7361, '출연영화': ['다만 악에서 구하소서', '사바하', '보좌관 – 세상을 움직이는 사람들']}
# 28 {'배우이름': 'RM', '랭킹': 35, '흥행지수': 7258, '다른 이름': '김남준; 방탄소년단; RM', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 29 {'배우이름': '임영웅', '랭킹': 36, '흥행지수': 7205, '출연영화': ['미스터트롯: 더 무비', '뽕숭아학당', '2020 트롯 어워즈']}
# 30 {'배우이름': '이성욱', '랭킹': 37, '흥행지수': 6934, '출연영화': ['유체이탈자', '365 : 운명을 거스르는 1년', '삼진그룹 영어토익반']}
# 31 {'배우이름': '진', '랭킹': 40, '흥행지수': 6221, '다른 이름': '김석진; 방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 32 {'배우이름': '영탁', '랭킹': 41, '흥행지수': 6004, '출연영화': ['미스터트롯: 더 무비', '뽕숭아학당', '꼰대인턴 방구석 팬미팅 : 끝나지 말란 말야']}
# 33 {'배우이름': '신승환', '랭킹': 43, '흥행지수': 5641, '출연영화': ['들리나요?', '국제수사', '목격자']}
# 34 {'배우이름': '홍시호', '랭킹': 46, '흥행지수': 5244, '출연영화': ['극장판 포켓몬스터 뮤츠의 역습 EVOLUTION', '마징가 Z 인피니티', '극장판 레이디버그: 미라클스톤의 비밀']}
# 35 {'배우이름': '슈가', '랭킹': 47, '흥행지수': 5184, '다른 이름': '민윤기; 방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 36 {'배우이름': '김성오', '랭킹': 48, '흥행지수': 5093, '출연영화': ['해적: 도깨비 깃발', '우아한 친구들', '해치지않아']}
# 37 {'배우이름': '이찬원', '랭킹': 49, '흥행지수': 4803, '출연영화': ['미스터트롯: 더 무비', '뽕숭아학당']}
# 38 {'배우이름': '제이홉', '랭킹': 51, '흥행지수': 4147, '다른 이름': '정호석; 방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 39 {'배우이름': '이규형', '랭킹': 52, '흥행지수': 4044, '출연영화': ['디바', '하이바이, 마마!', '로망']}
# 40 {'배우이름': '이민혁', '랭킹': 53, '흥행지수': 3932, '다른 이름': '비투비', '출연영화': ['검객', '대장금이 보고있다', '정글의 법칙 in 라스트 인도양']}
# 41 {'배우이름': '박정민', '랭킹': 56, '흥행지수': 3683, '출연영화': ['사냥의 시간', '다만 악에서 구하소서', '사바하']}
# 42 {'배우이름': '정동원', '랭킹': 57, '흥행지수': 3602, '출연영화': ['미스터트롯: 더 무비']}
# 43 {'배우이름': '장민혁', '랭킹': 58, '흥행지수': 3547, '출연영화': ['기기괴괴 성형수', '원더랜드', '극장판 파워레인저 갤럭시포스 VS 스페이스 스쿼드']}
# 44 {'배우이름': '김창옥', '랭킹': 59, '흥행지수': 3385, '출연영화': ['들리나요?', '김창옥쇼', '모두의 강연 가치 들어요']}
# 45 {'배우이름': '지민', '랭킹': 61, '흥행지수': 3110, '다른 이름': '박지민, 방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 46 {'배우이름': '양동근', '랭킹': 63, '흥행지수': 2547, '출연영화': ['나의 판타집', '야차', '365 : 운명을 거스르는 1년']}
# 47 {'배우이름': '최승훈', '랭킹': 64, '흥행지수': 2463, '출연영화': ['기기괴괴 성형수', '극장판 오소마츠 6쌍둥이', '포켓몬 제너레이션스']}
# 48 {'배우이름': '장민호', '랭킹': 65, '흥행지수': 2402, '출연영화': ['미스터트롯: 더 무비', '뽕숭아학당']}
# 49 {'배우이름': '성혁', '랭킹': 66, '흥행지수': 2256, '다른 이름': '홍성혁', '출연영화': ['바람과 구름과 비', '국제수사', '트랩']}
# 50 {'배우이름': '김소형', '랭킹': 67, '흥행지수': 2111, '출연영화': ['기기괴괴 성형수', '극장판 원피스 스탬피드', '줌 피시 월드']}
# 51 {'배우이름': '뷔', '랭킹': 68, '흥행지수': 2074, '다른 이름': '방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '방탄소년단 월드 투어 - 러브 유어셀프 인 서울']}
# 52 {'배우이름': '임지호', '랭킹': 69, '흥행지수': 1930, '다른 이름': '방랑식객', '출연영화': ['정글의 법칙 with 헌터와 셰프', '밥정', '잘 먹고 잘 사는 법, 식사하셨어요?']}
# 53 {'배우이름': '박성웅', '랭킹': 73, '흥행지수': 1440, '출연영화': ['루갈', '6.15 남북공동선언 20주년 평화음악회 <길을 걷다>', '바닷길 선발대']}
# 54 {'배우이름': '박성광', '랭킹': 74, '흥행지수': 1408, '출연영화': ['기기괴괴 성형수', '끝까지 간다', '할리우드에서 아침을']}
# 55 {'배우이름': '김환진', '랭킹': 78, '흥행지수': 1203, '출연영화': ['뽀로로 극장판 보물섬 대모험', '극장판 짱구는 못말려: 신혼여행 허리케인~ 사라진 아빠!', '극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~']}
# 56 {'배우이름': '김희재', '랭킹': 79, '흥행지수': 1201, '출연영화': ['미스터트롯: 더 무비']}
# 57 {'배우이름': '신용우', '랭킹': 80, '흥행지수': 1167, '출연영화': ['극장판 요괴워치: 포에버 프렌즈', '극장판 오소마츠 6쌍둥이', '레드슈즈']}
# 58 {'배우이름': '이상윤', '랭킹': 83, '흥행지수': 1080, '출연영화': ['진짜 농구, 핸섬 타이거즈', '오케이 마담', 'VIP']}
# 59 {'배우이름': '정국', '랭킹': 85, '흥행지수': 1037, '다른 이름': '전정국; 방탄소년단', '출연영화': ['브레이크 더 사일런스: 더 무비', '브링 더 소울 : 더 무비', '추석특집 ALL ABOUT BTS']}
# 60 {'배우이름': '허준호', '랭킹': 90, '흥행지수': 885, '출연영화': ['킹덤 시즌 2', '미씽: 그들이 있었다', '나이트메어 서커스']}
# 61 {'배우이름': '권오중', '랭킹': 93, '흥행지수': 832, '출연영화': ['부활: 그 증거', '중독', '이상한 나라의 며느리']}
# 62 {'배우이름': '홍경', '랭킹': 94, '흥행지수': 787, '출연영화': ['동네변호사 조들호 2 : 죄와 벌', '결백', '저글러스']}
# 63 {'배우이름': '김의성', '랭킹': 95, '흥행지수': 761, '출연영화': ['나의 촛불', '국민 여러분!', '아스달 연대기']}
# 64 {'배우이름': '배정남', '랭킹': 96, '흥행지수': 720, '출연영화': ['영웅', '미스터 주: 사라진 VIP', '오케이 마담']}
# 65 {'배우이름': '황창영', '랭킹': 97, '흥행지수': 704, '출연영화': ['기기괴괴 성형수', '극장판 오소마츠 6쌍둥이', '극장판 원피스 스탬피드']}
# 66 {'배우이름': '태항호', '랭킹': 98, '흥행지수': 688, '출연영화': ['좀비탐정', '파이프라인', '드라마 스페셜 - 웬 아이가 보았네']}
# 67 {'배우이름': '홍진욱', '랭킹': 102, '흥행지수': 612, '출연영화': ['더 프린세스 : 도둑맞은 공주', '극장판 엉덩이 탐정: 텐텐마을의 수수께끼', '프린스 코기']}
# 68 {'배우이름': '안성기', '랭킹': 103, '흥행지수': 597, '다른 이름': '安聖基', '출연영화': ['한산: 용의 출현', '사자', '종이꽃']}
# 69 {'배우이름': '고창석', '랭킹': 104, '흥행지수': 590, '출연영화': ['카운트(가제)', '싱크홀', '드림 (가제)']}
# 70 {'배우이름': '양흥주', '랭킹': 106, '흥행지수': 574, '출연영화': ['남매의 여름밤', '춘천, 춘천']}
# 71 {'배우이름': '남도형', '랭킹': 107, '흥행지수': 559, '출연영화': ['더 프린세스 : 도둑맞은 공주', '매지컬 : 공주를 웃겨라', '극장판 엉덩이 탐정: 텐텐마을의 수수께끼']}
# 72 {'배우이름': '이용규', '랭킹': 109, '흥행지수': 499, '다른 이름': 'Lee Yonggyu', '출연영화': ['부활: 그 증거']}
# 73 {'배우이름': '박철민', '랭킹': 110, '흥행지수': 494, '출연영화': ['아무도 모른다', '누가 뭐래도', '애월']}
# 74 {'배우이름': '권해효', '랭킹': 111, '흥행지수': 491, '출연영화': ['아무도 모른다', '반도', '도망친 여자']}
# 75 {'배우이름': '차순배', '랭킹': 116, '흥행지수': 393, '출연영화': ['사바하', '빅이슈', '결백']}
# 76 {'배우이름': '서반석', '랭킹': 119, '흥행지수': 355, '출연영화': ['더 프린세스 : 도둑맞은 공주', '슈퍼 레이스', '기기괴괴 성형수']}
# 77 {'배우이름': '이어령', '랭킹': 121, '흥행지수': 333, '출연영화': ['부활: 그 증거', '이어령의 100년 서재', '8020 이어령 학당']}
# 78 {'배우이름': '장광', '랭킹': 122, '흥행지수': 327, '출연영화': ['매지컬 : 공주를 웃겨라', '가나의 혼인잔치: 언약', '화양연화 - 삶이 꽃이 되는 순간']}
# 79 {'배우이름': '김혜성', '랭킹': 125, '흥행지수': 297, '출연영화': ['종이꽃', '매드독', '파워레인저 닌자포스 공룡주군전']}
# 80 {'배우이름': '정인겸', '랭킹': 126, '흥행지수': 295, '출연영화': ['본 어게인', '신의 한 수: 귀수편', '아이템']}
# 81 {'배우이름': '서영재', '랭킹': 128, '흥행지수': 286, '출연영화': ['다시 만난 날들']}
# 82 {'배우이름': '정우성', '랭킹': 129, '흥행지수': 264, '출연영화': ['보호자', '보호자', '강철비2: 정상회담']}
# 83 {'배우이름': '김명곤', '랭킹': 133, '흥행지수': 240, '출연영화': ['늙은 부부이야기: 스테이지 무비', '강철비2: 정상회담', '구르는 수레바퀴']}
# 84 {'배우이름': '유연석', '랭킹': 134, '흥행지수': 232, '다른 이름': '안연석', '출연영화': ['슬기로운 의사생활', '강철비2: 정상회담', '새해전야']}
# 85 {'배우이름': '박승준', '랭킹': 135, '흥행지수': 230, '출연영화': ['남매의 여름밤']}
# 86 {'배우이름': '신정근', '랭킹': 136, '흥행지수': 217, '출연영화': ['강철비2: 정상회담', '호텔 델루나', '미스터 션샤인']}
# 87 {'배우이름': '류수영', '랭킹': 137, '흥행지수': 202, '다른 이름': '어남선', '출연영화': ['아이앰 고추장', '퍼펙트 라이프', '나의 판타집']}
# 88 {'배우이름': '한이진', '랭킹': 139, '흥행지수': 197, '다른 이름': '한성용', '출연영화': ['런 보이 런', '결백', '련희와 연희']}
# 89 {'배우이름': '박성영', '랭킹': 140, '흥행지수': 197, '출연영화': ['빅트립: 아기팬더 배달 대모험', '슈퍼 베어', '극장판 원피스 스탬피드']}
# 90 {'배우이름': '최로운', '랭킹': 142, '흥행지수': 175, '출연영화': ['나를 구하지 마세요', '해피 투게더', '엽기적인 그녀']}
# 91 {'배우이름': '윤제문', '랭킹': 145, '흥행지수': 164, '출연영화': ['타짜: 원 아이드 잭', '후쿠오카', '헤븐: 행복의 나라로(가제)']}
# 92 {'배우이름': '윤찬영', '랭킹': 146, '흥행지수': 160, '출연영화': ['아무도 모른다', '젊은이의 양지', '17세의 조건']}
# 93 {'배우이름': '이제훈', '랭킹': 149, '흥행지수': 136, '출연영화': ['사냥의 시간', '도굴', '트래블러 시즌 1']}
# 94 {'배우이름': '이봉준', '랭킹': 151, '흥행지수': 125, '출연영화': ['매지컬 : 공주를 웃겨라', '극장판 원피스 스탬피드', '엘도라도']}
# 95 {'배우이름': '이재용', '랭킹': 152, '흥행지수': 124, '출연영화': ['프리즈너', '내가 가장 예뻤을 때', '강철비2: 정상회담']}
# 96 {'배우이름': '기주봉', '랭킹': 153, '흥행지수': 121, '출연영화': ['69세', '풀잎들', '강변호텔']}
# 97 {'배우이름': '김상동', '랭킹': 156, '흥행지수': 115, '출연영화': ['남매의 여름밤']}
# 98 {'배우이름': '안내상', '랭킹': 158, '흥행지수': 109, '출연영화': ['하이바이, 마마!', '어서와', '유별나! 문셰프']}
# 99 {'배우이름': '신석호', '랭킹': 160, '흥행지수': 106, '출연영화': ['도망친 여자', '강변호텔']}
# 100 {'배우이름': '조우진', '랭킹': 161, '흥행지수': 101, '다른 이름': '조신제', '출연영화': ['도굴', '서복', '봉오동 전투']}
# 101 {'배우이름': '김수현', '랭킹': 162, '흥행지수': 98, '출연영화': ['호흡', '결백', '절처봉생 이것이 사주다']}
# 102 {'배우이름': '손종학', '랭킹': 163, '흥행지수': 93, '출연영화': ['꼰대인턴', '모범형사', '악의 꽃']}
# 103 {'배우이름': '강동원', '랭킹': 164, '흥행지수': 89, '출연영화': ['반도', '브로커(가제)', '쓰나미 LA']}
# 104 {'배우이름': '김준경', '랭킹': 167, '흥행지수': 84, '출연영화': ['69세']}
# 105 {'배우이름': '조선묵', '랭킹': 169, '흥행지수': 77, '출연영화': ['황무지 5월의 고해', '붉은 바캉스 검은 웨딩', '보리울의 여름']}
# 106 {'배우이름': '김영재', '랭킹': 170, '흥행지수': 71, '출연영화': ['하이에나', '비밀의 숲 2', '양자물리학']}
# 107 {'배우이름': '기호', '랭킹': 171, '흥행지수': 67, '다른 이름': '피원하모니 ; P1Harmony ; 윤기호', '출연영화': ['피원에이치: 새로운 세계의 시작']}
# 108 {'배우이름': '이영석', '랭킹': 173, '흥행지수': 66, '출연영화': ['날씨가 좋으면 찾아가겠어요', '구르는 수레바퀴', '드라마 스테이지 - 오우거']}
# 109 {'배우이름': '지창욱', '랭킹': 176, '흥행지수': 62, '출연영화': ['편의점 샛별이', '날 녹여주오', '조작된 도시']}
# 110 {'배우이름': '테오', '랭킹': 177, '흥행지수': 62, '다른 이름': '피원하모니 ; P1Harmony ; 최태양', '출연영화': ['피원에이치: 새로운 세계의 시작']}
# 111 {'배우이름': '이상보', '랭킹': 178, '흥행지수': 58, '출연영화': ['메피스토']}
# 112 {'배우이름': '김중기', '랭킹': 180, '흥행지수': 57, '출연영화': ['69세', '웰컴2라이프', '탐정: 리턴즈']}
# 113 {'배우이름': '지웅', '랭킹': 181, '흥행지수': 57, '다른 이름': '피원하모니 ; P1Harmony ; 최지웅', '출연영화': ['피원에이치: 새로운 세계의 시작']}
# 114 {'배우이름': '인탁', '랭킹': 184, '흥행지수': 52, '다른 이름': '피원하모니 ; P1Harmony ; 황인탁', '출연영화': ['피원에이치: 새로운 세계의 시작']}
# 115 {'배우이름': '김준배', '랭킹': 185, '흥행지수': 51, '다른 이름': '김태한', '출연영화': ['바람의 언덕', '구르는 수레바퀴', '마왕의 딸 이리샤']}
# 116 {'배우이름': '구교환', '랭킹': 186, '흥행지수': 51, '출연영화': ['반도', '메기', '메기']}
# 117 {'배우이름': '종섭', '랭킹': 188, '흥행지수': 46, '다른 이름': '피원하모니 ; P1Harmony ; 김종섭', '출연영화': ['피원에이치: 새로운 세계의 시작']}
# 118 {'배우이름': '최정원', '랭킹': 189, '흥행지수': 45, '다른 이름': 'UN; 유엔', '출연영화': ['나의 이름', '정글의 법칙 in 멕시코', '보그맘']}
# 119 {'배우이름': '정진영', '랭킹': 190, '흥행지수': 45, '출연영화': ['(아는 건 별로 없지만) 가족입니다', '사바하', '사라진 시간']}
# 120 {'배우이름': '심규혁', '랭킹': 191, '흥행지수': 39, '출연영화': ['프린스 코기', '극장판 오소마츠 6쌍둥이', '극장판 원피스 스탬피드']}
# 121 {'배우이름': '정용화', '랭킹': 195, '흥행지수': 36, '다른 이름': '씨엔블루;CNBLUE', '출연영화': ['트롯신이 떴다', '신드롬맨', '섬총사']}
# 122 {'배우이름': '김정균', '랭킹': 196, '흥행지수': 36, '출연영화': ['나의 이름', '추적 60분']}
# 123 {'배우이름': '하준', '랭킹': 197, '흥행지수': 36, '다른 이름': '송하준', '출연영화': ['시네마틱드라마 SF8', '시네마틱드라마 SF8 - 블링크', '미씽: 그들이 있었다']}
# 124 {'배우이름': '고윤', '랭킹': 198, '흥행지수': 35, '출연영화': ['이별식당', '크리미널마인드', '몬스터']}
# 125 {'배우이름': '임원희', '랭킹': 199, '흥행지수': 34, '출연영화': ['도굴', '낭만닥터 김사부 2', '재혼의 기술']}
# 126 {'배우이름': '최한', '랭킹': 200, '흥행지수': 34, '출연영화': ['레드슈즈', '극장판 원피스 스탬피드', '날씨의 아이']}
# 127 {'배우이름': '김민재', '랭킹': 201, '흥행지수': 34, '출연영화': ['반도', '소방관', '방법']}
# 128 {'배우이름': '홍희용', '랭킹': 202, '흥행지수': 33, '출연영화': ['구르는 수레바퀴', '식구', '기화']}
# 129 {'배우이름': '유형준', '랭킹': 207, '흥행지수': 30, '출연영화': ['스윈들러']}
# 130 {'배우이름': '한흥만', '랭킹': 208, '흥행지수': 29, '출연영화': ['웰컴 투 X-월드']}
# 131 {'배우이름': '이장원', '랭킹': 209, '흥행지수': 28, '출연영화': ['뽀로로 극장판 보물섬 대모험', '극장판 엉덩이 탐정: 화려한 사건 수첩', '날씨의 아이']}
# 132 {'배우이름': '김태훈', '랭킹': 210, '흥행지수': 28, '다른 이름': 'Kim Tae-hoon', '출연영화': ['좋은 사람', '드라마 스테이지 - 통화권이탈', '킹덤 시즌 2']}
# 133 {'배우이름': '한신', '랭킹': 214, '흥행지수': 23, '출연영화': ['레오나르도 다 빈치', '베이블레이드 버스트 갓 : 갓 발키리의 탄생', '킹 오브 프리즘-프라이드 더 히어로-']}
# 134 {'배우이름': '김도윤', '랭킹': 216, '흥행지수': 22, '다른 이름': '김주년', '출연영화': ['반도', '방법', '럭키 몬스터 ']}
# 135 {'배우이름': '김병옥', '랭킹': 220, '흥행지수': 19, '출연영화': ['메피스토', '리갈하이', '시크릿 마더']}
# 136 {'배우이름': '정상현', '랭킹': 221, '흥행지수': 18, '출연영화': ['나의 이름']}
# 137 {'배우이름': '이준영', '랭킹': 224, '흥행지수': 16, '출연영화': ['구르는 수레바퀴', '비밀과 거짓말', '빛나라 은수']}
# 138 {'배우이름': '정해인', '랭킹': 225, '흥행지수': 15, '출연영화': ['반의반', '유열의 음악앨범', '시동']}
# 139 {'배우이름': '김록경', '랭킹': 226, '흥행지수': 15, '출연영화': ['여름날', '잔칫날', '나의 불행에는 이유가 있다']}
# 140 {'배우이름': '이승호', '랭킹': 227, '흥행지수': 15, '출연영화': ['악사들']}
# 141 {'배우이름': '송영창', '랭킹': 228, '흥행지수': 15, '다른 이름': '宋永彰', '출연영화': ['정직한 후보', '모두의 거짓말', '말모이']}
# 142 {'배우이름': '김희찬', '랭킹': 229, '흥행지수': 15, '출연영화': ['보이스 비!!', '7월7일', '자체발광 오피스']}
# 143 {'배우이름': '강신성일', '랭킹': 230, '흥행지수': 15, '다른 이름': '강신영', '출연영화': ['야관문 : 욕망의 꽃', '나는 별일없이 산다', '동방의 빛']}
# 144 {'배우이름': '전배수', '랭킹': 233, '흥행지수': 13, '출연영화': ['＃살아있다', '어서와', '더 킹 : 영원의 군주']}
# 145 {'배우이름': '이현행', '랭킹': 234, '흥행지수': 12, '출연영화': ['악사들']}
# 146 {'배우이름': '김용준', '랭킹': 235, '흥행지수': 11, '출연영화': ['극장판 헬로카봇 : 달나라를 구해줘!', '극장판 헬로카봇: 백악기 시대', '고스트 메신저 극장판']}
# 147 {'배우이름': '유재석', '랭킹': 236, '흥행지수': 10, '출연영화': ['식스센스', '미추리 8-1000 시즌 2', '놀면 뭐하니?']}
# 148 {'배우이름': '이준혁', '랭킹': 238, '흥행지수': 10, '출연영화': ['365 : 운명을 거스르는 1년', '비밀의 숲 2', '소방관']}
# 149 {'배우이름': '이정수', '랭킹': 239, '흥행지수': 9, '출연영화': ['악사들']}
# 150 {'배우이름': '편한셈', '랭킹': 241, '흥행지수': 9, '출연영화': ['나의 이름']}
# 151 {'배우이름': '이현욱', '랭킹': 242, '흥행지수': 9, '출연영화': ['＃살아있다', '써치', '타인은 지옥이다']}
# 152 {'배우이름': '김영민', '랭킹': 244, '흥행지수': 9, '출연영화': ['부부의 세계', '사생활', '찬실이는 복도 많지']}
# 153 {'배우이름': '김진규', '랭킹': 245, '흥행지수': 8, '출연영화': ['사랑하는 사람아 3', '가고파', '심장이 뛰네']}
# 154 {'배우이름': '유준상', '랭킹': 246, '흥행지수': 8, '출연영화': ['우아한 친구들', '소년들', '왜그래 풍상씨']}
# 155 {'배우이름': '이학주', '랭킹': 248, '흥행지수': 8, '출연영화': ['싱크홀', '부부의 세계', '야식남녀']}
# 156 {'배우이름': '김승수', '랭킹': 249, '흥행지수': 7, '출연영화': ['오지GO with 코무바울루', '바람과 구름과 비', '야식남녀']}
# 157 {'배우이름': '정인기', '랭킹': 250, '흥행지수': 7, '출연영화': ['굿캐스팅', '소리꾼', '잔칫날']}
# 158 {'배우이름': '박기태', '랭킹': 254, '흥행지수': 6, '출연영화': ['악사들']}
# 159 {'배우이름': '송영규', '랭킹': 255, '흥행지수': 6, '출연영화': ['하이에나', '야구소녀', '검법남녀 시즌 2']}
# 160 {'배우이름': '곽진석', '랭킹': 256, '흥행지수': 6, '출연영화': ['나는보리', '베를린', '우린 액션배우다']}
# 161 {'배우이름': '이천희', '랭킹': 257, '흥행지수': 6, '출연영화': ['문제적 보스', '바다가 들린다', '애월']}
# 162 {'배우이름': '동방우', '랭킹': 258, '흥행지수': 6, '다른 이름': '명계남', '출연영화': ['세상에서 제일 예쁜 내 딸', '아름다운 세상', '메기']}
# 163 {'배우이름': '신민재', '랭킹': 259, '흥행지수': 6, '출연영화': ['근본주의자', '고봉수 감독 단편선', '어서오시게스트하우스']}
# 164 {'배우이름': '오지호', '랭킹': 262, '흥행지수': 5, '출연영화': ['프리즈너', '태백권', '왜그래 풍상씨']}
# 165 {'배우이름': '김상중', '랭킹': 263, '흥행지수': 5, '출연영화': ['나쁜 녀석들: 더 무비', '더 뱅커', '더 뱅커 프롤로그']}
# 166 {'배우이름': '트위스트 김', '랭킹': 265, '흥행지수': 5, '출연영화': ['수사반장 트위스트 김', '그림일기', '공포특급 (V)']}
# 167 {'배우이름': '정의한', '랭킹': 266, '흥행지수': 5, '출연영화': ['극장판 도라에몽: 진구의 달 탐사기', '빅샤크3: 젤리몬스터 대소동', '고 피쉬!']}
# 168 {'배우이름': '정의한', '랭킹': 267, '흥행지수': 5, '출연영화': ['극장판 도라에몽: 진구의 달 탐사기', '빅샤크3: 젤리몬스터 대소동', '고 피쉬!']}
# 169 {'배우이름': '민형식', '랭킹': 270, '흥행지수': 5, '출연영화': ['몽마르트 파파']}
# 170 {'배우이름': '성유빈', '랭킹': 276, '흥행지수': 5, '출연영화': ['카운트(가제)', '윤희에게', '입술은 안돼요(가제)']}
# 171 {'배우이름': '최진욱', '랭킹': 277, '흥행지수': 4, '출연영화': ['걸작', '걸작', '걸작']}
# 172 {'배우이름': '신재훈', '랭킹': 278, '흥행지수': 4, '출연영화': ['어서오시게스트하우스', '내 마음의 고향']}
# 173 {'배우이름': '곽동연', '랭킹': 280, '흥행지수': 4, '출연영화': ['야구소녀', '모두의 주방', '닥터탐정']}
# 174 {'배우이름': '윤일봉', '랭킹': 282, '흥행지수': 4, '다른 이름': '尹一峰', '출연영화': ['환희', '해병 묵시록', '비는 사랑을 타고']}
# 175 {'배우이름': '김학선', '랭킹': 284, '흥행지수': 4, '출연영화': ['브람스를 좋아하세요?', '윤희에게', '아름다운 세상']}
# 176 {'배우이름': '이예춘', '랭킹': 285, '흥행지수': 4, '출연영화': ['위자료', '무작정 상경', '재생']}
# 177 {'배우이름': '이선균', '랭킹': 287, '흥행지수': 4, '출연영화': ['기생충', '킹메이커', '미스터 주: 사라진 VIP']}
# 178 {'배우이름': '이예춘', '랭킹': 288, '흥행지수': 4, '출연영화': ['위자료', '무작정 상경', '재생']}
# 179 {'배우이름': '이선균', '랭킹': 290, '흥행지수': 4, '출연영화': ['시베리아 선발대', '검사내전', '기생충']}
# 180 {'배우이름': '이병헌', '랭킹': 294, '흥행지수': 4, '다른 이름': 'Byung-hun Lee;BH Lee', '출연영화': ['비상선언', '콘크리트 유토피아', '백두산']}
# 181 {'배우이름': '이성민', '랭킹': 296, '흥행지수': 3, '출연영화': ['대외비: 권력의 탄생(가제)', '머니게임', '제8일의 밤']}
# 182 {'배우이름': '박종환', '랭킹': 301, '흥행지수': 3, '출연영화': ['우린같이 영화를보고 소설을읽어', '타인은 지옥이다', '오매불망: 타인은 지옥이다']}
# 183 {'배우이름': '김명건', '랭킹': 305, '흥행지수': 3, '출연영화': ['걸작', '갈까부다', '걸작']}
# 184 {'배우이름': '김범진', '랭킹': 306, '흥행지수': 3, '출연영화': ['어서오시게스트하우스', '간택 - 여인들의 전쟁', '열두밤']}
# 185 {'배우이름': '송강호', '랭킹': 307, '흥행지수': 3, '출연영화': ['비상선언', '브로커(가제)', '기생충']}
# 186 {'배우이름': '오동민', '랭킹': 310, '흥행지수': 3, '출연영화': ['마음 울적한 날엔', '출사표', '타짜: 원 아이드 잭']}
# 187 {'배우이름': '감우성', '랭킹': 312, '흥행지수': 3, '출연영화': ['바람이 분다-너와 내가 우리였던 그 날처럼', '바람이 분다', '키스 먼저 할까요?']}
# 188 {'배우이름': '최덕문', '랭킹': 315, '흥행지수': 3, '출연영화': ['애비규환', '머니게임', '써치']}
# 189 {'배우이름': '오동민', '랭킹': 316, '흥행지수': 3, '출연영화': ['마음 울적한 날엔', '출사표', '타짜: 원 아이드 잭']}
# 190 {'배우이름': '하명중', '랭킹': 318, '흥행지수': 3, '출연영화': ['주문진', '주문진', '어머니는 죽지 않는다']}
# 191 {'배우이름': '서현우', '랭킹': 321, '흥행지수': 3, '출연영화': ['유체이탈자', '악의 꽃', '시네마틱드라마 SF8']}
# 192 {'배우이름': '김태희', '랭킹': 323, '흥행지수': 3, '출연영화': ['바람의 언덕', '재꽃', '스틸 플라워']}
# 193 {'배우이름': '오희준', '랭킹': 324, '흥행지수': 3, '출연영화': ['계약우정', '우리, 사랑했을까', '경우의 수']}
# 194 {'배우이름': '강하늘', '랭킹': 325, '흥행지수': 3, '다른 이름': '김하늘', '출연영화': ['트래블러 - 아르헨티나', '해적: 도깨비 깃발', '비와 당신의 이야기']}
# 195 {'배우이름': '강길우', '랭킹': 327, '흥행지수': 3, '출연영화': ['마음 울적한 날엔', '파도를 걷는 소년', '한강에게']}
# 196 {'배우이름': '강길우', '랭킹': 331, '흥행지수': 3, '출연영화': ['마음 울적한 날엔', '파도를 걷는 소년', '한강에게']}
# 197 {'배우이름': '박상준', '랭킹': 334, '흥행지수': 3, '출연영화': ['걸작', '갈까부다']}
# 198 {'배우이름': '손상연', '랭킹': 336, '흥행지수': 2, '출연영화': ['연애미수', '어제 일은 모두 괜찮아', '벌새']}
# 199 {'배우이름': '김동완', '랭킹': 337, '흥행지수': 2, '다른 이름': '신화;Shinhwa', '출연영화': ['외식하는 날 2', '소리꾼', '독립원정대의 하루, 살이']}
# 200 {'배우이름': '지현준', '랭킹': 339, '흥행지수': 2, '출연영화': ['하이에나', '남산의 부장들', '원티드']}
# 201 {'배우이름': '이창민', '랭킹': 341, '흥행지수': 2, '출연영화': ['더 프린세스 : 도둑맞은 공주', '극장판 오소마츠 6쌍둥이', '빅트립: 아기팬더 배달 대모험']}
# 202 {'배우이름': '유민규', '랭킹': 343, '흥행지수': 2, '출연영화': ['앙상블', '블랙독', '명불허전']}
# 203 {'배우이름': '백일섭', '랭킹': 344, '흥행지수': 2, '출연영화': ['모던패밀리', '꽃보다 할배 리턴즈', '월드 스페셜 프렌즈']}
# 204 {'배우이름': '강재철', '랭킹': 345, '흥행지수': 2, '출연영화': ['걸작']}
# 205 {'배우이름': '박성근', '랭킹': 346, '흥행지수': 2, '출연영화': ['출사표', '비밀의 숲 2', '사생활']}
# 206 {'배우이름': '백서빈', '랭킹': 347, '흥행지수': 2, '출연영화': ['파이터', '산상수훈', '아빠는 예쁘다']}
# 207 {'배우이름': '곽민규', '랭킹': 348, '흥행지수': 2, '출연영화': ['파도를 걷는 소년', '이장', '내가 사는 세상']}
# 208 {'배우이름': '이해영', '랭킹': 352, '흥행지수': 2, '출연영화': ['더 킹 : 영원의 군주', '비밀의 숲 2', '애비규환']}
# 209 {'배우이름': '이준기', '랭킹': 353, '흥행지수': 2, '출연영화': ['악의 꽃', '무법 변호사', '레지던트 이블: 파멸의 날']}
# 210 {'배우이름': '유해진', '랭킹': 354, '흥행지수': 2, '출연영화': ['휴머니멀', '삼시세끼 어촌편 5', '봉오동 전투']}
# 211 {'배우이름': '정석용', '랭킹': 356, '흥행지수': 2, '출연영화': ['우아한 친구들', '나를 사랑한 스파이', '사이코메트리 그녀석']}
# 212 {'배우이름': '박지일', '랭킹': 357, '흥행지수': 2, '출연영화': ['더 게임:0시를 향하여', '포레스트', '날아라 개천용']}
# 213 {'배우이름': '이대엽', '랭킹': 358, '흥행지수': 2, '출연영화': ['내! 아바디 오마니', '이도백화', '먼여행 긴터널']}
# 214 {'배우이름': '김민준', '랭킹': 359, '흥행지수': 2, '출연영화': ['우리, 사랑했을까', '소리꾼', '볼 빨간 당신']}
# 215 {'배우이름': '하용수', '랭킹': 360, '흥행지수': 2, '출연영화': ['천화', '투게더', '박대박']}
# 216 {'배우이름': '유해진', '랭킹': 362, '흥행지수': 2, '출연영화': ['휴머니멀', '삼시세끼 어촌편 5', '스페인 하숙']}
# 217 {'배우이름': '정석용', '랭킹': 364, '흥행지수': 2, '출연영화': ['우아한 친구들', '나를 사랑한 스파이', '사이코메트리 그녀석']}
# 218 {'배우이름': '박지일', '랭킹': 365, '흥행지수': 2, '출연영화': ['더 게임:0시를 향하여', '포레스트', '날아라 개천용']}
# 219 {'배우이름': '탁우석', '랭킹': 368, '흥행지수': 2, '출연영화': ['나의 위험한 아내', '검색어를 입력하세요 WWW', '산상수훈']}
# 220 {'배우이름': '민병우', '랭킹': 370, '흥행지수': 2, '다른 이름': 'Min Byung Woo', '출연영화': ['몽마르트 파파', '몽마르트 파파', '그 강아지 그 고양이']}
# 221 {'배우이름': '하정우', '랭킹': 373, '흥행지수': 2, '다른 이름': '김성훈; 河正宇', '출연영화': ['클로젯', '백두산', 'PMC: 더 벙커']}
# 222 {'배우이름': '하명진', '랭킹': 374, '흥행지수': 2, '출연영화': ['걸작', '걸작']}
# 223 {'배우이름': '이태형', '랭킹': 377, '흥행지수': 2, '출연영화': ['남산의 부장들', '소원을 말해봐']}
# 224 {'배우이름': '이봉근', '랭킹': 381, '흥행지수': 1, '출연영화': ['로또싱어', '소리꾼']}
# 225 {'배우이름': '정무성', '랭킹': 383, '흥행지수': 1, '다른 이름': '정무지', '출연영화': ['소리꾼', '귀향, 끝나지 않은 이야기', '귀향']}
# 226 {'배우이름': '이승훈', '랭킹': 384, '흥행지수': 1, '출연영화': ['드라마 스페셜 - 참치와 돌고래', '안녕, 형아', '왕의 남자']}
# 227 {'배우이름': '주석태', '랭킹': 386, '흥행지수': 1, '출연영화': ['브람스를 좋아하세요?', '구미호뎐', '왓칭']}
# 228 {'배우이름': '최무룡', '랭킹': 387, '흥행지수': 1, '다른 이름': '崔戊龍', '출연영화': ['덫', '덫', '연산군']}
# 229 {'배우이름': '태인호', '랭킹': 388, '흥행지수': 1, '다른 이름': '박상연', '출연영화': ['영혼수선공', '국민 여러분!', '블랙독']}
# 230 {'배우이름': '장인한', '랭킹': 389, '흥행지수': 1, '다른 이름': '장인환', '출연영화': ['내 머리 속의 지우개', '하면 된다', '소년기']}
# 231 {'배우이름': '장동휘', '랭킹': 391, '흥행지수': 1, '출연영화': ['만무방', '전국구', '잡초들의 봄']}
# 232 {'배우이름': '강두', '랭킹': 392, '흥행지수': 1, '출연영화': ['성혜의 나라', '안녕, 프란체스카 시즌3']}
# 233 {'배우이름': '홍완표', '랭킹': 393, '흥행지수': 1, '출연영화': ['카오산 탱고', '드림 (가제)', '사월의 끝']}
# 234 {'배우이름': '김주헌', '랭킹': 395, '흥행지수': 1, '출연영화': ['언택트', '낭만닥터 김사부 2', '사이코지만 괜찮아']}
# 235 {'배우이름': '김승호', '랭킹': 397, '흥행지수': 1, '출연영화': ['짧은 시간 긴 시간', '짧은 시간 긴 시간', '족보']}
# 236 {'배우이름': '민승연', '랭킹': 399, '흥행지수': 1, '출연영화': ['광주비디오: 사라진 4시간']}
# 237 {'배우이름': '장항선', '랭킹': 401, '흥행지수': 1, '다른 이름': '장봉수', '출연영화': ['변산', '밥상의 신', '설 특집 밥상의 신']}
# 238 {'배우이름': '설경구', '랭킹': 403, '흥행지수': 1, '다른 이름': '薛景求', '출연영화': ['야차', '소년들', '킹메이커']}
# 239 {'배우이름': '유순웅', '랭킹': 404, '흥행지수': 1, '출연영화': ['이장', '남한산성', '2014 드라마 페스티벌 - 하우스, 메이트']}
# 240 {'배우이름': '이도국', '랭킹': 406, '흥행지수': 1, '출연영화': ['사냥의 시간', '클로젯', '남산의 부장들']}
# 241 {'배우이름': '이민우', '랭킹': 409, '흥행지수': 1, '출연영화': ['TV소설 저 하늘에 태양이', '조선총잡이', '인생법정 이것은 실화다']}
# 242 {'배우이름': '김정팔', '랭킹': 411, '흥행지수': 1, '출연영화': ['머니게임', '봄이 오나 봄', '청춘빌라 살인사건']}
# 243 {'배우이름': '설경구', '랭킹': 415, '흥행지수': 1, '다른 이름': '薛景求', '출연영화': ['야차', '소년들', '킹메이커']}
# 244 {'배우이름': '유순웅', '랭킹': 416, '흥행지수': 1, '출연영화': ['이장', '남한산성', '2014 드라마 페스티벌 - 하우스, 메이트']}
# 245 {'배우이름': '이도국', '랭킹': 418, '흥행지수': 1, '출연영화': ['사냥의 시간', '클로젯', '남산의 부장들']}
# 246 {'배우이름': '김승훈', '랭킹': 419, '흥행지수': 1, '출연영화': ['블랙독', '남산의 부장들', '1987']}
# 247 {'배우이름': '김병춘', '랭킹': 421, '흥행지수': 1, '출연영화': ['우리, 사랑했을까', '불새 2020', '초면에 사랑합니다']}
# 248 {'배우이름': '김승훈', '랭킹': 424, '흥행지수': 1, '출연영화': ['블랙독', '남산의 부장들', '1987']}
# 249 {'배우이름': '성홍일', '랭킹': 426, '흥행지수': 1, '출연영화': ['동주', '조류인간', '기화']}
# 250 {'배우이름': '정현준', '랭킹': 427, '흥행지수': 1, '출연영화': ['특송', '기생충']}
# 251 {'배우이름': '김승훈', '랭킹': 429, '흥행지수': 1, '출연영화': ['블랙독', '남산의 부장들', '1987']}
# 252 {'배우이름': '성홍일', '랭킹': 431, '흥행지수': 1, '출연영화': ['동주', '조류인간', '기화']}
# 253 {'배우이름': '정현준', '랭킹': 432, '흥행지수': 1, '출연영화': ['특송', '기생충']}
# 254 {'배우이름': '김상순', '랭킹': 433, '흥행지수': 1, '출연영화': ['아내', '제국의 아침', '명성황후']}
# 255 {'배우이름': '임권택', '랭킹': 434, '흥행지수': 1, '출연영화': ['녹차의 중력', '백두 번째 구름', '화장']}
# 256 {'배우이름': '임성철', '랭킹': 435, '흥행지수': 1, '출연영화': ['소리꾼', '귀향, 끝나지 않은 이야기', '귀향']}
# 257 {'배우이름': '최성관', '랭킹': 439, '흥행지수': 1, '출연영화': ['계약 커플', '뽕 3', '짧은 여행의 끝']}
# 258 {'배우이름': '우현', '랭킹': 440, '흥행지수': 1, '출연영화': ['굿캐스팅', '편의점 샛별이', '국민 여러분!']}
# 259 {'배우이름': '김희라', '랭킹': 442, '흥행지수': 1, '다른 이름': '김영목', '출연영화': ['시', '하얀 거짓말', '묘도야화']}
# 260 {'배우이름': '문성근', '랭킹': 444, '흥행지수': 1, '다른 이름': '文盛瑾', '출연영화': ['아무도 모른다', '화양연화 - 삶이 꽃이 되는 순간', '북간도의 십자가']}
# 261 {'배우이름': '김홍표', '랭킹': 445, '흥행지수': 1, '출연영화': ['아내를 죽였다', '1919 유관순', '어게인']}
# 262 {'배우이름': '이석형', '랭킹': 448, '흥행지수': 1, '출연영화': ['하트', '꿈의 제인']}
# 263 {'배우이름': '김희갑', '랭킹': 449, '흥행지수': 1, '출연영화': ['88짝궁들', '그 여자 사람잡네', '유관순']}
# 264 {'배우이름': '김민상', '랭킹': 450, '흥행지수': 1, '출연영화': ['루갈', '사생활', '초면에 사랑합니다']}
# 265 {'배우이름': '박성준', '랭킹': 451, '흥행지수': 1, '출연영화': ['마음 울적한 날엔', '야식남녀', '럭키 몬스터 ']}
# 266 {'배우이름': '형영선', '랭킹': 452, '흥행지수': 1, '출연영화': ['벌새', '설']}
# 267 {'배우이름': '박서준', '랭킹': 453, '흥행지수': 1, '출연영화': ['드림 (가제)', '콘크리트 유토피아', '이태원 클라쓰']}
# 268 {'배우이름': '박명훈', '랭킹': 454, '흥행지수': 1, '출연영화': ['기생충', '사랑의 불시착', '재꽃']}
# 269 {'배우이름': '이가섭', '랭킹': 455, '흥행지수': 1, '출연영화': ['도어락', '니나 내나', '폭력의 씨앗']}
# 270 {'배우이름': '김동원', '랭킹': 456, '흥행지수': 1, '출연영화': ['선유락', '잡초들의 봄', '엄마 결혼식']}
# 271 {'배우이름': '김홍표', '랭킹': 457, '흥행지수': 1, '출연영화': ['아내를 죽였다', '1919 유관순', '어게인']}
# 272 {'배우이름': '이석형', '랭킹': 460, '흥행지수': 1, '출연영화': ['하트', '꿈의 제인']}
# 273 {'배우이름': '엄태구', '랭킹': 464, '흥행지수': 1, '출연영화': ['구해줘 시즌 2', '장도연의 타로뷰: 구해줘2', '판소리 복서']}
# 274 {'배우이름': '조재성', '랭킹': 467, '흥행지수': 1, '출연영화': ['사랑하는 사람아', '그들은 태양을 쏘았다', "자유부인 '81"]}
# 275 {'배우이름': '박상증', '랭킹': 469, '흥행지수': 1, '출연영화': ['광주비디오: 사라진 4시간']}
# 276 {'배우이름': '이양희', '랭킹': 471, '흥행지수': 0, '다른 이름': '성민수', '출연영화': ['클로젯', '남산의 부장들', '국가부도의 날']}
# 277 {'배우이름': '신재휘', '랭킹': 474, '흥행지수': 0, '출연영화': ['애비규환', '아무도 모른다', '미스터 기간제']}
# 278 {'배우이름': '류덕환', '랭킹': 476, '흥행지수': 0, '출연영화': ['아무도 모른다', '난폭한 기록', '특별근로감독관 조장풍']}
# 279 {'배우이름': '박원상', '랭킹': 477, '흥행지수': 0, '출연영화': ['더 게임:0시를 향하여', '더 킹 : 영원의 군주', '불량한 가족']}
# 280 {'배우이름': '맹봉학', '랭킹': 480, '흥행지수': 0, '출연영화': ['녹색물질', '상견례 하는 날', '식객']}
# 281 {'배우이름': '허장강', '랭킹': 486, '흥행지수': 0, '다른 이름': '許長江', '출연영화': ['빨간 구두', '조약돌', '잔류 첩자']}
# 282 {'배우이름': '장병관', '랭킹': 487, '흥행지수': 0, '출연영화': ['빅샤크: 매직체인지', '빅샤크2: 해저2만리', '매직빈']}
# 283 {'배우이름': '맹봉학', '랭킹': 491, '흥행지수': 0, '출연영화': ['녹색물질', '상견례 하는 날', '식객']}
# 284 {'배우이름': '민진웅', '랭킹': 496, '흥행지수': 0, '출연영화': ['아무도 모른다', '초콜릿', '말모이']}
# 285 {'배우이름': '신재휘', '랭킹': 500, '흥행지수': 0, '출연영화': ['애비규환', '아무도 모른다', '미스터 기간제']}
# 286 {'배우이름': '류덕환', '랭킹': 503, '흥행지수': 0, '출연영화': ['아무도 모른다', '난폭한 기록', '특별근로감독관 조장풍']}
# 287 {'배우이름': '허장강', '랭킹': 505, '흥행지수': 0, '다른 이름': '許長江', '출연영화': ['빨간 구두', '조약돌', '잔류 첩자']}
# 288 {'배우이름': '장병관', '랭킹': 510, '흥행지수': 0, '출연영화': ['빅샤크: 매직체인지', '빅샤크2: 해저2만리', '매직빈']}
# 289 {'배우이름': '이양희', '랭킹': 513, '흥행지수': 0, '다른 이름': '성민수', '출연영화': ['클로젯', '남산의 부장들', '국가부도의 날']}
# 290 {'배우이름': '신재휘', '랭킹': 515, '흥행지수': 0, '출연영화': ['애비규환', '아무도 모른다', '미스터 기간제']}
# 291 {'배우이름': '이대연', '랭킹': 518, '흥행지수': 0, '다른 이름': 'Lee Dae Yan', '출연영화': ['아이템', '저스티스', '드라마 스페셜 - 굿바이 비원']}
# 292 {'배우이름': '장인섭', '랭킹': 520, '흥행지수': 0, '출연영화': ['그 남자의 기억법', '루갈', '저스티스']}
# 293 {'배우이름': '최준영', '랭킹': 521, '흥행지수': 0, '출연영화': ['유열의 음악앨범', '판소리 복서', '아워 바디']}
# 294 {'배우이름': '최재호', '랭킹': 522, '흥행지수': 0, '출연영화': ['계백', '보석비빔밥', '사막의 샘']}
# 295 {'배우이름': '남연우', '랭킹': 524, '흥행지수': 0, '출연영화': ['방법', '초미의 관심사', '팡파레']}
# 296 {'배우이름': '김종구', '랭킹': 525, '흥행지수': 0, '출연영화': ['엑시트', '욕창', '바벨']}
# 297 {'배우이름': '남연우', '랭킹': 527, '흥행지수': 0, '출연영화': ['방법', '초미의 관심사', '팡파레']}
# 298 {'배우이름': '김종구', '랭킹': 528, '흥행지수': 0, '출연영화': ['욕창', '바벨', '국민 여러분!']}
# 299 {'배우이름': '엄지성', '랭킹': 532, '흥행지수': 0, '출연영화': ['범죄도시', '보고싶다', '국제시장']}
# 300 {'배우이름': '박성택', '랭킹': 533, '흥행지수': 0, '출연영화': ['박열', '다이너마이트맨', '공모자들']}
# 301 {'배우이름': '차지현', '랭킹': 534, '흥행지수': 0, '출연영화': ['비행']}
# 302 {'배우이름': '최영열', '랭킹': 536, '흥행지수': 0, '출연영화': ['루비', '디스코2000']}
# 303 {'배우이름': '독고성', '랭킹': 537, '흥행지수': 0, '출연영화': ['깡패수업3', '투맨', '네 멋대로 해라']}
# 304 {'배우이름': '황건', '랭킹': 538, '흥행지수': 0, '출연영화': ['날씨가 좋으면 찾아가겠어요', '시간의 종말', '일대일']}
# 305 {'배우이름': '송명진', '랭킹': 541, '흥행지수': 0, '다른 이름': '송규현', '출연영화': ['하트', '농담']}
# 306 {'배우이름': '이종원', '랭킹': 542, '흥행지수': 0, '출연영화': ['엑스엑스', '(아는 건 별로 없지만) 가족입니다', '나를 사랑한 스파이']}
# 307 {'배우이름': '채재일', '랭킹': 544, '흥행지수': 0, '출연영화': ['시간의 종말']}
# 308 {'배우이름': '김창은', '랭킹': 545, '흥행지수': 0, '출연영화': ['창은']}
# 309 {'배우이름': '이정웅', '랭킹': 546, '흥행지수': 0, '출연영화': ['다른 나라에서', 'TV소설 약속', '이별아닌 이별']}
# 310 {'배우이름': '김진순', '랭킹': 547, '흥행지수': 0, '출연영화': ['창은']}
# 311 {'배우이름': '장인섭', '랭킹': 550, '흥행지수': 0, '출연영화': ['그 남자의 기억법', '루갈', '저스티스']}
# 312 {'배우이름': '최준영', '랭킹': 551, '흥행지수': 0, '출연영화': ['유열의 음악앨범', '판소리 복서', '아워 바디']}
# 313 {'배우이름': '최재호', '랭킹': 552, '흥행지수': 0, '출연영화': ['계백', '보석비빔밥', '사막의 샘']}
# 314 {'배우이름': '안지호', '랭킹': 554, '흥행지수': 0, '출연영화': ['아무도 모른다', '보희와 녹양', '우리집']}
# 315 {'배우이름': '김경익', '랭킹': 556, '흥행지수': 0, '출연영화': ['포크레인', '살아남은 아이', '인 허 플레이스']}
# 316 {'배우이름': '김재록', '랭킹': 557, '흥행지수': 0, '출연영화': ['나의 위험한 아내', '욕창', '꿈꾸는 나비']}
# 317 {'배우이름': '최일화', '랭킹': 559, '흥행지수': 0, '출연영화': ['철수씨와 02', '투깝스', '꾼']}
# 318 {'배우이름': '임형태', '랭킹': 560, '흥행지수': 0, '출연영화': ['메이킹 필름', '카센타', '돌연변이']}
# 319 {'배우이름': '정준원', '랭킹': 562, '흥행지수': 0, '출연영화': ['동네변호사 조들호 2 : 죄와 벌', 'VIP', '드라마 스페셜 - 굿바이 비원']}
# 320 {'배우이름': '안지호', '랭킹': 563, '흥행지수': 0, '출연영화': ['아무도 모른다', '보희와 녹양', '우리집']}
# 321 {'배우이름': '김경익', '랭킹': 565, '흥행지수': 0, '출연영화': ['포크레인', '살아남은 아이', '인 허 플레이스']}
# 322 {'배우이름': '최일화', '랭킹': 566, '흥행지수': 0, '출연영화': ['철수씨와 02', '투깝스', '꾼']}
# 323 {'배우이름': '김재록', '랭킹': 567, '흥행지수': 0, '출연영화': ['나의 위험한 아내', '욕창', '꿈꾸는 나비']}
# 324 {'배우이름': '이종원', '랭킹': 568, '흥행지수': 0, '출연영화': ['엑스엑스', '(아는 건 별로 없지만) 가족입니다', '나를 사랑한 스파이']}
# 325 {'배우이름': '채재일', '랭킹': 570, '흥행지수': 0, '출연영화': ['시간의 종말']}
# 326 {'배우이름': '김창은', '랭킹': 571, '흥행지수': 0, '출연영화': ['창은']}
# 327 {'배우이름': '이정웅', '랭킹': 572, '흥행지수': 0, '출연영화': ['다른 나라에서', 'TV소설 약속', '이별아닌 이별']}
# 328 {'배우이름': '김진순', '랭킹': 573, '흥행지수': 0, '출연영화': ['창은']}
# 329 {'배우이름': '최민철', '랭킹': 576, '흥행지수': 0, '출연영화': ['해치', '악인전', '오 나의 귀신님']}
# 330 {'배우이름': '박성택', '랭킹': 577, '흥행지수': 0, '출연영화': ['박열', '다이너마이트맨', '공모자들']}
# 331 {'배우이름': '차지현', '랭킹': 578, '흥행지수': 0, '출연영화': ['비행']}
# 332 {'배우이름': '독고성', '랭킹': 580, '흥행지수': 0, '출연영화': ['깡패수업3', '투맨', '네 멋대로 해라']}
# 333 {'배우이름': '황건', '랭킹': 581, '흥행지수': 0, '출연영화': ['날씨가 좋으면 찾아가겠어요', '시간의 종말', '일대일']}
# 334 {'배우이름': '엄지성', '랭킹': 585, '흥행지수': 0, '출연영화': ['범죄도시', '보고싶다', '국제시장']}
# 335 {'배우이름': '김준한', '랭킹': 586, '흥행지수': 0, '출연영화': ['보호자', '슬기로운 의사생활', '봄밤']}
# 336 {'배우이름': '공형진', '랭킹': 587, '흥행지수': 0, '출연영화': ['미친사랑', '나도 CEO', '로마의 휴일']}
# 337 {'배우이름': '박세준', '랭킹': 588, '흥행지수': 0, '출연영화': ['팡파레', '더러워 정말', 'TV소설 누나의 거울']}

# %% [markdown]
# #### List 에 포함된 문자열 검색
# * $all 연산자 사용하면 순서에 상관 없이 값으로 찾을 수 있다.

# %%
col.count_documents({'출연영화':'아무도 모른다'})
#criteria = {'출연영화':'아무도 모른다'}
#criteria = {'$or':[{'출연영화':'아무도 모른다'},{'출연영화':'특별근로감독관 조장풍'}]}
#criteria = {'출연영화':['아무도 모른다','특별근로감독관 조장풍']}
criteria = {'출연영화':{'$all':['아무도 모른다','특별근로감독관 조장풍']}}
# projection = {
#     '_id':0,'랭킹':1,'배우이름':1,'흥행지수':1,'다른 이름':1,'출연영화':1
# }
print_find_document(criteria,projection)
# Out:
# 1 {'배우이름': '류덕환', '랭킹': 476, '흥행지수': 0, '출연영화': ['아무도 모른다', '난폭한 기록', '특별근로감독관 조장풍']}
# 2 {'배우이름': '류덕환', '랭킹': 503, '흥행지수': 0, '출연영화': ['아무도 모른다', '난폭한 기록', '특별근로감독관 조장풍']}

# %%
#### $sortByCount 연산자
sort = {
    '$sortByCount':'$소속사'
}
print_aggregate_document(sort)
