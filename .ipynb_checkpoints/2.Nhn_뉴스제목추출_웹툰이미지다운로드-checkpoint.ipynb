# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

url = 'https://news.naver.com/'
req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'
}

res = requests.get(url, headers=req_header)
# print(res.status_code)
# print('응답헤더 ',res.headers)
# print('요청헤더 ',res.request.headers)
if res.ok:
    #응답객체에서 텍스트 추출
    html = res.text
    #추출한 텍스트를 파싱하기 위해서 Beautifulsoup 객체를 생성
    soup = BeautifulSoup(html,'html.parser')
    #print(soup)
    print(len(soup.select('div')))
    atag_list = soup.select("a[href*='read.nhn']")
    print(type(atag_list), len(atag_list))
    for idx,atag in enumerate(atag_list,1):
        title = atag.text.strip()
        link = urljoin(url, atag['href'])
        print('-----')
        #print(atag)
        print(idx,title,link)
# Out:
# 126
# <class 'bs4.element.ResultSet'> 109
# -----
# 1 ‘도지사 재선-대선’, 이재명의 시선 향하는 곳은 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=421&aid=0004931312
# -----
# 2 "세상이 왜이래" 국감장 울려퍼진 '테스형'…웃… https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=015&aid=0004432857
# -----
# 3 옵티머스 재판 '폭로전' 예고…김재현 "로비의혹에 고통"(종합) https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=001&aid=0011949113
# -----
# 4 野 "국민들은 감정원 통계 못 믿는다" vs 與 "민간 통계는 한계 있다" (종합)[2020국감] https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=277&aid=0004773784
# -----
# 5 "文정부 들어 '非강남' 아파트 땅값 62% 올라 최대 상승" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=079&aid=0003419371
# -----
# 6 日 "후쿠시마 오염수 처분, 계속 미룰 수만은 없다" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=421&aid=0004931450
# -----
# 7 美 ‘종전선언 의구심’ 풀러 간 서훈… 의견차 못 좁힌 듯 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=021&aid=0002445980
# -----
# 8  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=025&aid=0003043908
# -----
# 9 "윤석열, 무소불위 놀아대더니 허수아비신세" 北의 조롱 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=025&aid=0003043908
# -----
# 10 '차기 대권' 이재명 20% vs 이낙연 17% https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=079&aid=0003419447
# -----
# 11 與, 진영 옵티머스 5억 투자에 "그도 피해자"…野 공세 차단 총력 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=009&aid=0004675971
# -----
# 12 '라임' 김봉현, 옥중 추가 폭로… "야당에도 억대 로비, 현직 검사도 접대" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=417&aid=0000606009
# -----
# 13 유승민 "김종철 연금개혁 제안 반가워…文, 노조 눈치 그만보라" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=366&aid=0000604575
# -----
# 14 충북도의회 전두환·노태우 동상 철거 조례 심사 또 보류 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=001&aid=0011949220
# -----
# 15  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=009&aid=0004675984
# -----
# 16 부동산 유튜버의 빌라 추천…알고보니 본인이 지은 거? https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=009&aid=0004675984
# -----
# 17 '빅히트' 상장 후 이틀 연속 급락세…역대급 청약 흥행에도 결과 기대에 미치지 못한 까닭은? https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=022&aid=0003513378
# -----
# 18 '건배사 논란' 산은 회장에 野 "정무감각 없다" 질타 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=001&aid=0011949283
# -----
# 19 [2020국감] 김현미 "전·월세 시장 안정에 어느 정도 시간 걸릴 것" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=277&aid=0004773798
# -----
# 20 알려주는 보험사가 없다…고층 아파트 화재보험료 절약법 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=015&aid=0004432861
# -----
# 21 코로나 2차 충격 가시화, 정부 "30만 일자리+소비패키지" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=008&aid=0004485358
# -----
# 22  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=469&aid=0000544856
# -----
# 23 '화장실 불법촬영' KBS 개그맨, 징역 2년 선고 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=469&aid=0000544856
# -----
# 24 검사도 갸우뚱…"옵티머스 제안서 허술한데 어떻게 1조를" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0003043909
# -----
# 25 '궁금한 이야기Y' 골목식당 덮죽 표절 진상…지옥같은 현장실습 전말은? https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=031&aid=0000562934
# -----
# 26 KBS 여자화장실 몰카 개그맨 '징역 2년' https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=014&aid=0004511891
# -----
# 27 음주사고 후 60㎞ 도주 30대, 화장실 급해 찾은 곳이 경찰서(종합) https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011949286
# -----
# 28 1인당 50만원 청년특별지원금 2차 신청 닷새 만에 5만2천명 몰려 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011949284
# -----
# 29  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=011&aid=0003811940
# -----
# 30 렘데시비르 국내 부작용 11건...WHO선 치료 효과 없다는 연구도 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=011&aid=0003811940
# -----
# 31 금연 20분 후부터 15년 뒤까지 일어나는 변화 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=296&aid=0000046812
# -----
# 32 교회협 "'성소수자 축복' 이동환 목사 죄 없다…종교재판, 혐오 광풍 상징" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=421&aid=0004931378
# -----
# 33 "남편 말릴 수 없다"는 말, 전 웃을 수가 없습니다 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=047&aid=0002288247
# -----
# 34 중국의 적반하장…BTS 트집 잡곤 “한국언론이 선정보도” https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=023&aid=0003569166
# -----
# 35 한국기독교교회協 “‘성소수자 축복’ 중징계, 교회 내 혐오 광풍” https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=469&aid=0000544819
# -----
# 36  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=022&aid=0003513376
# -----
# 37 매장 철수하고 수백억 적자인데 일본 불매운동 끝날 조짐이라고? [이동준의 일본은 지금] https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=022&aid=0003513376
# -----
# 38 [올댓차이나] "중국, 방적회사에 호주산 면화 수입중단 지시" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=003&aid=0010130764
# -----
# 39 日 "후쿠시마 오염수 처분, 계속 미룰 수만은 없다" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=421&aid=0004931450
# -----
# 40 [영상] 중국 신무기 '카미카제' 드론 공개...효과는 글쎄 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=015&aid=0004432855
# -----
# 41 日경산상 "원전오염수 처분방침 결정 마냥 미룰 수 없어" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011949251
# -----
# 42 글로벌 車 회사들 "코로나 장기화에 '공급 지도' 새판짜기…中 벗어나 다변화" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=366&aid=0000604577
# -----
# 43  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=469&aid=0000544851
# -----
# 44 삼성전자, 8월 세계 스마트폰 판매 1위…화웨이와 격차 벌렸다 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=469&aid=0000544851
# -----
# 45 영어가 즐겁다...AI 기술 옷 입고 영어교사 나선 펭수 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=584&aid=0000010972
# -----
# 46 비상장 벤처 창업주, 10개 복수의결권 발행 허용 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=092&aid=0002202173
# -----
# 47 "애플 아이폰12, 과거 아이폰 같은 '슈퍼 사이클' 어렵다" https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=015&aid=0004432829
# -----
# 48 카카오 나와!…우버·SKT 동맹이 모빌리티 판도 바꾼다 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=008&aid=0004485339
# -----
# 49 '모빌리티 분사' SK텔레콤, 카카오 넘어 해외까지 노린다 https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=293&aid=0000031366
# -----
# 50 "세상 왜 이래~" 국감장서 울린 '테스형'에 빵 터진 김현미 https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0003043870&date=20201016&type=2&rankingSeq=1&rankingSectionId=100
# -----
# 51 “왜이리 힘들어” 국감서 ‘테스형’ 노래에 빵터진 김현미 https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003569145&date=20201016&type=2&rankingSeq=2&rankingSectionId=100
# -----
# 52 "아! 테스형"에 빵 터진 김현미…"전세없어요" 현장 목소리에 "송구" https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000604464&date=20201016&type=1&rankingSeq=3&rankingSectionId=100
# -----
# 53 강경화 시아버지 별세…요트 사러 미국行 이일병, 장례 참석 못해 https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=009&aid=0004675709&date=20201016&type=1&rankingSeq=4&rankingSectionId=100
# -----
# 54 與 탐내던 이수정이 야당 가니, 친문 “친일파X”“더럽다” https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003569124&date=20201016&type=1&rankingSeq=5&rankingSectionId=100
# -----
# 55 "테스형, 집값이 왜이래" 빵터진 김현미…부동산 지적에 "송구" https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0004485303&date=20201016&type=1&rankingSeq=6&rankingSectionId=100
# -----
# 56 강경화 시아버지 별세···“못말린다”던 남편 이일병 교수 불참한듯 https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=011&aid=0003811785&date=20201016&type=1&rankingSeq=7&rankingSectionId=100
# -----
# 57 차기 대선주자 1위 이재명…2위 이낙연에 오차범위 내 앞서 [갤럽] https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0003043861&date=20201016&type=1&rankingSeq=8&rankingSectionId=100
# -----
# 58 이수정 교수 “내가 국민의힘으로 간 이유는…" https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=009&aid=0004675645&date=20201016&type=1&rankingSeq=9&rankingSectionId=100
# -----
# 59 [레이더P] 이낙연 지지율 10%대로 떨어져…1위는 이재명 20% https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=009&aid=0004675859&date=20201016&type=1&rankingSeq=10&rankingSectionId=100
# -----
# 60 "건물 팔아 21억 번 가수, 도시재생사업 융자받아 건물 또 사" https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0003043875&date=20201016&type=1&rankingSeq=1&rankingSectionId=101
# -----
# 61 건물로 21억 번 가수, 정부 돈으로 건물 또 샀다 https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=014&aid=0004511690&date=20201016&type=1&rankingSeq=2&rankingSectionId=101
# -----
# 62 "주식 환불 안되나요"…빅히트 고점에 물린 개미들 절규 https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0004761219&date=20201016&type=1&rankingSeq=3&rankingSectionId=101
# -----
# 63 아미들만 산 빅히트, 오늘도 20%↓…20만원대 깨질까[이슈+] https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004432670&date=20201016&type=1&rankingSeq=4&rankingSectionId=101
# -----
# 64 정부, 24번째 부동산 대책 예고…시장선 "아무것도 하지 마라" https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0004432742&date=20201016&type=1&rankingSeq=5&rankingSectionId=101
# -----
# 65 서민 아우성 외면하더니…홍남기가 당하자 ‘세입자 계약갱신 명시’ 추진 https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=005&aid=0001371402&date=20201016&type=1&rankingSeq=6&rankingSectionId=101
# -----
# 66 정부, 소비쿠폰 다시 뿌리고 30만개 직접 일자리 만든다(종합) https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=421&aid=0004930883&date=20201016&type=1&rankingSeq=7&rankingSectionId=101
# -----
# 67 20억 번 가수 A씨, 정부 도시재생 융자 받아 건물 샀다 https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=011&aid=0003811855&date=20201016&type=1&rankingSeq=8&rankingSectionId=101
# -----
# 68 "테스형~" 나온 국감장…빵 터진 김현미 "전세 해결할 것"(종합) https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=421&aid=0004931182&date=20201016&type=1&rankingSeq=9&rankingSectionId=101
# -----
# 69 술 마시고 쾅, 본인 부담금 최대 1억6500만원 ‘부메랑’ https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=028&aid=0002516516&date=20201016&type=1&rankingSeq=10&rankingSectionId=101
# -----
# 70 [단독]박유천 "통장 100만원"…성폭행 고소인에 1년째 배상 안해 https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0
https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003569132&date=20201016&type=1&rankingSeq=8&rankingSectionId=105
# -----
# 108 ‘타다의 눈물’ 지운 박재욱의 쏘카, 일냈다… 600억 투자 유치, 유니콘 등극 https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=022&aid=0003513293&date=20201016&type=1&rankingSeq=9&rankingSectionId=105
# -----
# 109 지금은 사라진 달 자기장이 태양으로부터 고대 지구 지켜 https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0011948673&date=20201016&type=1&rankingSeq=10&rankingSectionId=105

# %% [markdown]
# ### 웹툰 이미지 다운로드

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail.nhn?titleId=735661&no=53&amp;weekday=fri'
}

img_urls = [
        'https://image-comic.pstatic.net/webtoon/735661/53/20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_1.jpg',
        'https://image-comic.pstatic.net/webtoon/735661/53/20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_2.jpg',
        'https://image-comic.pstatic.net/webtoon/735661/53/20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_3.jpg'
]
for img_url in img_urls:
    res = requests.get(img_url, headers=req_header)
    print(res.status_code)
    if res.ok:
        #응답객체에서 binary(이진) 데이터를 가져올때는 content 속성을 사용한다
        img_data = res.content
        #img_url에서 file 이름만 꺼내기
        file_name = os.path.basename(img_url)
        #print(file_name)
        #binary 데이터를 file로 저장하기 
        with open(file_name,'wb') as file:
            print(f'Writing to {file_name} ({len(img_data)}) bytes')
            file.write(img_data)
# Out:
# 200
# Writing to 20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_1.jpg (112100) bytes
# 200
# Writing to 20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_2.jpg (216632) bytes
# 200
# Writing to 20200917155434_e1cb5ef2b9ef5b933f8895a2b9b7f4d6_IMAG01_3.jpg (135534) bytes

# %% [markdown]
# ### 특정 웹툰 페이지의 모든 image를 다운로드 받기
# * soup.select("img[src$='jpg']")
# * img 폴더를 생성하고 그 아래에 파일을 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import re

main_url = 'https://comic.naver.com/webtoon/detail.nhn?titleId=712362&no=94&amp;weekday=fri'
res = requests.get(main_url)
print(res.status_code)
if res.ok:
    html = res.text
    soup = BeautifulSoup(html,'html.parser')
    
    print(len(soup.select("img[src$='.jpg']")))
    img_url_list = []
    for img_url in soup.select("img[src$='jpg']"):
        img_url_list.append(img_url['src'])

img_url_list[0:3]
# Out:
# 200
# 57
# ['https://shared-comic.pstatic.net/thumb/webtoon/712362/thumbnail/thumbnail_IMAG04_ac694463-dc14-4362-b66d-8f20ee06017d.jpg',
#  'https://image-comic.pstatic.net/webtoon/712362/94/20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_1.jpg',
#  'https://image-comic.pstatic.net/webtoon/712362/94/20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_2.jpg']

# %%
#img 디렉토리 생성
#img 디렉토리가 없으면
if not os.path.isdir('img'):
    os.mkdir('img')

# %%
#image_url_list에 있는 url로 요청해서 image들을 다운로드 하기
for idx,img_url in enumerate(img_url_list,1):
    print(f'---> 다운로드 번호 {idx}')
    req_header = {
        'referer':main_url
    }
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_name = os.path.basename(img_url)
        with open('img/'+file_name,'wb') as file:
            print(f'파일명 :{file_name} ({len(img_data)}) bytes')
            file.write(img_data)
# Out:
# ---> 다운로드 번호 1
# 파일명 :thumbnail_IMAG04_ac694463-dc14-4362-b66d-8f20ee06017d.jpg (32102) bytes
# ---> 다운로드 번호 2
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_1.jpg (120839) bytes
# ---> 다운로드 번호 3
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_2.jpg (102260) bytes
# ---> 다운로드 번호 4
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_3.jpg (156656) bytes
# ---> 다운로드 번호 5
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_4.jpg (73441) bytes
# ---> 다운로드 번호 6
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_5.jpg (99572) bytes
# ---> 다운로드 번호 7
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_6.jpg (201003) bytes
# ---> 다운로드 번호 8
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_7.jpg (151338) bytes
# ---> 다운로드 번호 9
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_8.jpg (73271) bytes
# ---> 다운로드 번호 10
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_9.jpg (153137) bytes
# ---> 다운로드 번호 11
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_10.jpg (139634) bytes
# ---> 다운로드 번호 12
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_11.jpg (126055) bytes
# ---> 다운로드 번호 13
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_12.jpg (148571) bytes
# ---> 다운로드 번호 14
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_13.jpg (181065) bytes
# ---> 다운로드 번호 15
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_14.jpg (127447) bytes
# ---> 다운로드 번호 16
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_15.jpg (126282) bytes
# ---> 다운로드 번호 17
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_16.jpg (132622) bytes
# ---> 다운로드 번호 18
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_17.jpg (188352) bytes
# ---> 다운로드 번호 19
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_18.jpg (132702) bytes
# ---> 다운로드 번호 20
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_19.jpg (189236) bytes
# ---> 다운로드 번호 21
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_20.jpg (195953) bytes
# ---> 다운로드 번호 22
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_21.jpg (159069) bytes
# ---> 다운로드 번호 23
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_22.jpg (120476) bytes
# ---> 다운로드 번호 24
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_23.jpg (205842) bytes
# ---> 다운로드 번호 25
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_24.jpg (118733) bytes
# ---> 다운로드 번호 26
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_25.jpg (188156) bytes
# ---> 다운로드 번호 27
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_26.jpg (120851) bytes
# ---> 다운로드 번호 28
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_27.jpg (126224) bytes
# ---> 다운로드 번호 29
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_28.jpg (181762) bytes
# ---> 다운로드 번호 30
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_29.jpg (138336) bytes
# ---> 다운로드 번호 31
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_30.jpg (106290) bytes
# ---> 다운로드 번호 32
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_31.jpg (155457) bytes
# ---> 다운로드 번호 33
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_32.jpg (125034) bytes
# ---> 다운로드 번호 34
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_33.jpg (84119) bytes
# ---> 다운로드 번호 35
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_34.jpg (68203) bytes
# ---> 다운로드 번호 36
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_35.jpg (85811) bytes
# ---> 다운로드 번호 37
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_36.jpg (117945) bytes
# ---> 다운로드 번호 38
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_37.jpg (61524) bytes
# ---> 다운로드 번호 39
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_38.jpg (94352) bytes
# ---> 다운로드 번호 40
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_39.jpg (153601) bytes
# ---> 다운로드 번호 41
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_40.jpg (179257) bytes
# ---> 다운로드 번호 42
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_41.jpg (174245) bytes
# ---> 다운로드 번호 43
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_42.jpg (113743) bytes
# ---> 다운로드 번호 44
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_43.jpg (148381) bytes
# ---> 다운로드 번호 45
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_44.jpg (233131) bytes
# ---> 다운로드 번호 46
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_45.jpg (103718) bytes
# ---> 다운로드 번호 47
# 파일명 :20200924121949_aa6b0fd732e9b69f06ad265061e37edb_IMAG01_46.jpg (24802) bytes
# ---> 다운로드 번호 48
# 파일명 :banner_fe5cf3a7-02a4-43ae-8cee-9701a91d2e11.jpg (48671) bytes
# ---> 다운로드 번호 49
# 파일명 :thumbnail_202x120_a3dcb871-0d55-4da6-8550-0342256fbb0d.jpg (30063) bytes
# ---> 다운로드 번호 50
# 파일명 :thumbnail_202x120_a4508080-c76d-42a0-8b56-3570f6e0a198.jpg (26961) bytes
# ---> 다운로드 번호 51
# 파일명 :thumbnail_202x120_037fbd56-d472-40fa-8bf9-4af7966c8179.jpg (30054) bytes
# ---> 다운로드 번호 52
# 파일명 :thumbnail_202x120_943cfc31-3cf6-48d8-96bf-e0bd532764c7.jpg (42612) bytes
# ---> 다운로드 번호 53
# 파일명 :title_thumbnail_133631_125x101.jpg (3797) bytes
# ---> 다운로드 번호 54
# 파일명 :thumbnail_IMAG10_d093ab2d-a006-457b-92b5-1da097bc3af1.jpg (13133) bytes
# ---> 다운로드 번호 55
# 파일명 :thumbnail_IMAG10_bea8fafc-f043-4712-97e7-f9dbc5c61dcb.jpg (14696) bytes
# ---> 다운로드 번호 56
# 파일명 :title_thumbnail_20160601180804_t83x90.jpg (4436) bytes
# ---> 다운로드 번호 57
# 파일명 :thumbnail_IMAG10_34e13db4-712c-4556-9e32-5ecf17061293.jpg (11052) bytes

# %%
def download_image(title,url):
    import requests
    from bs4 import BeautifulSoup
    import os
    
    req_header = {
        'referer':url
    }
    
    res = requests.get(url)
    print(res.ok)
    if res.ok:
        soup = BeautifulSoup(res.text, 'html.parser')
        
        imgurl_list = []
        print(len(soup.select('img[src$=".jpg"]')))
        for img_tag in soup.select('img[src$=".jpg"]'):
            imgurl_list.append(img_tag['src'])
            #print(img_tag)
                
        #image를 저장할 디렉토리 생성
        
        #dir_name = 'img/' + title
        dir_name = os.path.join('img',title)
        print(dir_name)
        if not os.path.isdir(dir_name):
            os.makedirs(dir_name)
        
        for idx,img_url in enumerate(imgurl_list,1):
            print(idx, img_url)
            res = requests.get(img_url,headers=req_header)
            #print(res.status_code)
            if res.ok:
                img_data = res.content
                #print(len(img_data))
                file_name = os.path.basename(img_url)
                #print(file_name)
                file_name = dir_name + '/' + file_name
                with open(file_name,'wb') as file:
                    print('file 크기 : ', len(img_data))
                    file.write(img_data)
                
                
download_image('노력의결과',\
               'https://comic.naver.com/webtoon/detail.nhn?titleId=742889&no=32&weekday=mon')
# Out:
# True
# 19
# img\노력의결과
# 1 https://shared-comic.pstatic.net/thumb/webtoon/742889/thumbnail/thumbnail_IMAG04_ea91c3c6-0829-480f-8b13-87b991c3de02.jpg
# file 크기 :  19915
# 2 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_1.jpg
# file 크기 :  94574
# 3 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_2.jpg
# file 크기 :  131433
# 4 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_3.jpg
# file 크기 :  315022
# 5 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_4.jpg
# file 크기 :  204337
# 6 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_5.jpg
# file 크기 :  114517
# 7 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_6.jpg
# file 크기 :  167103
# 8 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_7.jpg
# file 크기 :  124008
# 9 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_8.jpg
# file 크기 :  177612
# 10 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_9.jpg
# file 크기 :  212016
# 11 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_10.jpg
# file 크기 :  148992
# 12 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_11.jpg
# file 크기 :  143213
# 13 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_12.jpg
# file 크기 :  122746
# 14 https://image-comic.pstatic.net/webtoon/742889/32/20201022222055_662b1c75f0796af33162d2ae658c09d8_IMAG01_13.jpg
# file 크기 :  159960
# 15 https://shared-comic.pstatic.net/thumb/webtoon/742889/29/thumbnail_202x120_adf4d5ac-cbbf-4e61-aa9a-2eefb6f900c8.jpg
# file 크기 :  19159
# 16 https://shared-comic.pstatic.net/thumb/webtoon/742889/30/thumbnail_202x120_e5758bb3-8ffc-45f1-b7bb-f50479ed3f70.jpg
# file 크기 :  10589
# 17 https://shared-comic.pstatic.net/thumb/webtoon/742889/31/thumbnail_202x120_256f2c4a-53b8-41a6-88cb-cdf843152eea.jpg
# file 크기 :  14903
# 18 https://shared-comic.pstatic.net/thumb/webtoon/742889/32/thumbnail_202x120_a60f1632-4ff6-4d5b-8d42-7668e59ce32d.jpg
# file 크기 :  5299
# 19 https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2020/06/08/dkskdltit/title_thumbnail_014542_125x101.jpg
# file 크기 :  4512

# %%
download_image('노력의결과',\
               'https://comic.naver.com/webtoon/detail.nhn?titleId=742889&no=32&weekday=mon')
# Out:
# True

# %% [markdown]
# #### 네이버 웹툰 홈에서 추천웹툰의 제목과 url 를 알아내기

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

main_url = 'https://comic.naver.com/index.nhn'

res = requests.get(main_url)
if res.ok:
    soup = BeautifulSoup(res.text,'html.parser')
    print(len(soup.select('div.genreRecomInfo2')))
    
    recom_webtoon_list = []
    for div_tag in soup.select('div.genreRecomInfo2'):
        recom_webtoon_dict = {}
        a_tag1 = div_tag.select('h6 a')[0]
        #웹툰제목
        title = a_tag1.text.strip()
        #웹툰의 url
        webtoon_url=urljoin(main_url, a_tag1['href'])
        
        #웹툰의 회차의 url
        a_tag2 = div_tag.select('p a')[0]
        webtoon_episode_url = urljoin(main_url,a_tag2['href'])
                
        recom_webtoon_dict['title'] = title
        recom_webtoon_dict['webtoon_url'] = webtoon_url
        recom_webtoon_dict['episode_url'] = webtoon_episode_url
        
        recom_webtoon_list.append(recom_webtoon_dict)
        
    #print(recom_webtoon_list)
# Out:
# 6

# %% [markdown]
# #### 6개의 만화의 제목과 회차url을 꺼내서 download_image() 함수를 호출한다.

# %%
for idx,webtoon in enumerate(recom_webtoon_list,1):
    print('---->>> ', idx, webtoon['title'])
    download_image(webtoon['title'],webtoon['episode_url'])
# Out:
# ---->>>  1 히어로메이커
# ---->>>  2 결혼생활 그림일기
# ---->>>  3 내일
# ---->>>  4 AI가 세상을 지배한다면
# ---->>>  5 단편.zip
# ---->>>  6 먹이
